# %% [markdown]
# # Securité informatique

# %% [markdown]
# Proteger les informations contre la manipulation non autorisée

# %%
x  = [1,2,3,4,5]

# %% [markdown]
# La cryptographie est un art et une science pour assurer quelque objectifs des services de sécurité confidentialité et Authentification.

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\toshiba'

# %%
from IPython.display import Image
Image(filename="img/security01.PNG", width=400, height=400)

# %% [markdown]
# ![title](img/security01.PNG)

# %% [markdown]
# <img src="img/security01.PNG" with="400" height="400">

# %% [markdown]
# <img src="img/security01.PNG">

# %% [markdown]
# $x = x^2 + 1$

# %% [markdown]
# $$ y = \int x dx$$
